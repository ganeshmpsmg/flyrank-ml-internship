# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshmpsmg/flyrank-ml-internship/blob/main/week2_Prompt_ladder_Content_Refreash_Priority_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# The main goal is to demonstrate iterative prompt engineering for 'Content Refresh Priority Prediction'. This involves starting with a baseline prompt and progressively adding layers (Clear Goal, Audience, Context, Output Format, Quality Criteria) to improve AI outputs. Finally, all generated prompts, representative AI outputs, and corresponding notes will be compiled into a professional document with a summary explaining the prompt ladder approach.

# %% [markdown]
# ## Generate Baseline Prompt
#
# ### Subtask:
# Create a weak, realistic baseline prompt for 'Content Refresh Priority Prediction'. Generate a representative AI output (5-8 lines) and include four notes: What changed, What improved, What still failed, and What to try next.

# %% [markdown]
# **Reasoning**:
# I will define the baseline prompt, simulate an AI output, and then document the required notes for this initial step.

# %%
baseline_prompt = "Predict content refresh priority."

baseline_output = (
    "Identify content that needs updating based on current relevance and performance."
    "Prioritize content that is outdated or underperforming."
    "Suggest refreshing content that aligns with current trends or user needs."
    "Consider content that has high traffic but low conversion rates for refresh."
    "Evaluate content based on last updated date and content decay."
)

baseline_notes = {
    "What changed": "This is the baseline prompt, so no changes from a previous iteration.",
    "What improved": "The AI provided a general, albeit vague, understanding of content refresh priority.",
    "What still failed": "The output is too generic and lacks specific criteria or actionable insights for prioritization. It's not tailored to any specific context or goal.",
    "What to try next": "Add a 'Clear Goal' layer to the prompt to define what success looks like for the prediction."
}

print("Baseline Prompt:\n" + baseline_prompt)
print("\nRepresentative AI Output:\n" + baseline_output)
print("\nNotes:")
for key, value in baseline_notes.items():
    print(f"- {key}: {value}")
# Out:
# Baseline Prompt:
# Predict content refresh priority.
#
# Representative AI Output:
# Identify content that needs updating based on current relevance and performance.Prioritize content that is outdated or underperforming.Suggest refreshing content that aligns with current trends or user needs.Consider content that has high traffic but low conversion rates for refresh.Evaluate content based on last updated date and content decay.
#
# Notes:
# - What changed: This is the baseline prompt, so no changes from a previous iteration.
# - What improved: The AI provided a general, albeit vague, understanding of content refresh priority.
# - What still failed: The output is too generic and lacks specific criteria or actionable insights for prioritization. It's not tailored to any specific context or goal.
# - What to try next: Add a 'Clear Goal' layer to the prompt to define what success looks like for the prediction.

# %% [markdown]
# ## Improve Prompt - Clear Goal
#
# ### Subtask:
# Add the 'Clear Goal' layer to the baseline prompt. Generate a representative AI output (5-8 lines) and include the four required notes.

# %% [markdown]
# **Reasoning**:
# I am defining the prompt with the 'Clear Goal' layer, simulating its AI output, and generating the corresponding notes as per the instructions for this subtask.

# %%
clear_goal_prompt = "Predict content refresh priority to maximize user engagement and conversion rates."

clear_goal_output = (
    "Identify content pieces with declining engagement or low conversion metrics."
    "Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups."
    "Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to user intent."
    "Consider A/B testing refreshed content versions to validate improvements in engagement and conversion."
    "Focus on content that directly supports business goals and revenue generation."
)

clear_goal_notes = {
    "What changed": "Added a 'Clear Goal' layer to the prompt: 'to maximize user engagement and conversion rates'.",
    "What improved": "The AI output is now more focused on specific metrics (engagement, conversion) and provides actionable suggestions directly tied to achieving the defined goal, moving beyond general advice.",
    "What still failed": "While more focused, the output still lacks specific audience context or detailed criteria for how to measure 'potential to increase'. It assumes a generic user base and doesn't specify the 'who' or 'how'.",
    "What to try next": "Add the 'Audience' layer to the prompt to define the target user group."
}

print("Clear Goal Prompt:\n" + clear_goal_prompt)
print("\nRepresentative AI Output:\n" + clear_goal_output)
print("\nNotes:")
for key, value in clear_goal_notes.items():
    print(f"- {key}: {value}")
# Out:
# Clear Goal Prompt:
# Predict content refresh priority to maximize user engagement and conversion rates.
#
# Representative AI Output:
# Identify content pieces with declining engagement or low conversion metrics.Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups.Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to user intent.Consider A/B testing refreshed content versions to validate improvements in engagement and conversion.Focus on content that directly supports business goals and revenue generation.
#
# Notes:
# - What changed: Added a 'Clear Goal' layer to the prompt: 'to maximize user engagement and conversion rates'.
# - What improved: The AI output is now more focused on specific metrics (engagement, conversion) and provides actionable suggestions directly tied to achieving the defined goal, moving beyond general advice.
# ...

# %% [markdown]
# ## Improve Prompt - Audience
#
# ### Subtask:
# Add the 'Audience' layer to the previous prompt. Generate a representative AI output (5-8 lines) and include the four required notes, specifically noting that adding the audience alone did not significantly improve prediction accuracy or quality in the 'What still failed' section.

# %% [markdown]
# **Reasoning**:
# I will define the prompt with the 'Audience' layer, simulate an AI output considering this audience, and then prepare the corresponding notes, ensuring the 'What still failed' note meets the specific requirement.

# %%
audience_prompt = clear_goal_prompt + " The target audience for this content is tech-savvy young professionals working in marketing roles."

audience_output = (
    "Identify content pieces with declining engagement or low conversion metrics relevant to tech-savvy marketing professionals."
    "Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups among this demographic."
    "Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to their professional needs."
    "Consider A/B testing refreshed content versions to validate improvements in engagement and conversion for this audience."
    "Focus on content that directly supports business goals and revenue generation by appealing to this specific user group."
)

audience_notes = {
    "What changed": "Added the 'Audience' layer to the prompt: 'The target audience for this content is tech-savvy young professionals working in marketing roles.'.",
    "What improved": "The AI output now vaguely considers the specified audience, mentioning 'tech-savvy marketing professionals' and 'their professional needs'.",
    "What still failed": "While the audience is mentioned, the output still lacks specific criteria or actionable insights tailored to *how* to measure 'potential to increase' for this audience, and adding the audience alone did not significantly improve prediction accuracy or overall quality beyond a generic mention.",
    "What to try next": "Add the 'Context' layer to the prompt to provide more specific operational details and constraints."
}

print("Audience Prompt:\n" + audience_prompt)
print("\nRepresentative AI Output:\n" + audience_output)
print("\nNotes:")
for key, value in audience_notes.items():
    print(f"- {key}: {value}")
# Out:
# Audience Prompt:
# Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles.
#
# Representative AI Output:
# Identify content pieces with declining engagement or low conversion metrics relevant to tech-savvy marketing professionals.Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups among this demographic.Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to their professional needs.Consider A/B testing refreshed content versions to validate improvements in engagement and conversion for this audience.Focus on content that directly supports business goals and revenue generation by appealing to this specific user group.
#
# Notes:
# ...

# %% [markdown]
# ## Improve Prompt - Context
#
# ### Subtask:
# Add the 'Context' layer to the previous prompt. Generate a representative AI output (5-8 lines) and include the four required notes.

# %% [markdown]
# **Reasoning**:
# I will define the prompt with the 'Context' layer, simulate its AI output, and generate the corresponding notes as per the instructions for this subtask.

# %%
context_layer = " The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards."

context_prompt = audience_prompt + context_layer

context_output = (
    "Identify blog posts, whitepapers, and case studies with declining views, downloads, or conversion rates, particularly those relevant to tech-savvy marketing professionals." \
    "Prioritize the 10-15 content pieces per quarter that, if refreshed, have the highest potential to increase engagement and conversions, utilizing A/B testing insights." \
    "Suggest updates that include clearer CTAs and improved readability, ensuring content aligns with professional needs and leverages CMS tracking data." \
    "Focus refresh efforts on content types and topics that historically drive high engagement and conversion for the target audience." \
    "Recommend A/B testing strategies for refreshed content versions to validate improvements in key metrics tracked by the CMS."
)

context_notes = {
    "What changed": "Added the 'Context' layer to the prompt, detailing content inventory, CMS tracking, team capacity (10-15 pieces/quarter), and available tools (A/B testing, analytics dashboards).",
    "What improved": "The AI output is now more specific, incorporating operational details like content types, metrics tracked by the CMS (views, downloads, conversion events), and the quarterly capacity for refreshing content. It also suggests using A/B testing insights.",
    "What still failed": "While improved, the output still lacks concrete, quantifiable metrics for what constitutes 'high potential' or 'declining' within the given context. It doesn't provide a specific framework for prioritization given the constraints, or how to use the dashboards effectively.",
    "What to try next": "Add the 'Output Format' layer to the prompt to ensure structured and easily digestible recommendations, potentially including specific fields or a table format."
}

print("Context Prompt:\n" + context_prompt)
print("\nRepresentative AI Output:\n" + context_output)
print("\nNotes:")
for key, value in context_notes.items():
    print(f"- {key}: {value}")
# Out:
# Context Prompt:
# Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles. The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards.
#
# Representative AI Output:
# ...

# %% [markdown]
# ## Improve Prompt - Output Format
#
# ### Subtask:
# Add the 'Output Format' layer to the previous prompt. Generate a representative AI output (5-8 lines) and include the four required notes.

# %% [markdown]
# **Reasoning**:
# I will define the prompt with the 'Output Format' layer, simulate its AI output in a structured format, and generate the corresponding notes as per the instructions for this subtask.

# %% [markdown]
# **Reasoning**:
# The previous code failed due to an unterminated string literal. I will fix this by using a triple-quoted string for the `output_format_output` variable to correctly handle multi-line strings.

# %%
output_format_layer = " Provide the recommendations in a structured markdown table with columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'."

output_format_prompt = context_prompt + output_format_layer

output_format_output = """
| Content ID | Content Type | Current Performance (Views, Downloads, Conversions) | Refresh Priority Score (1-10) | Key Reason for Refresh | Suggested Update Action |
|------------|--------------|-----------------------------------------------------|-------------------------------|------------------------|-------------------------|
| BLOG001    | Blog Post    | 1500, 50, 2%                                        | 9                             | Declining conversions  | Update CTA, add new stats |
| WP003      | Whitepaper   | 800, 100, 1%                                        | 8                             | Outdated data          | Research new trends, cite new sources |
| CS005      | Case Study   | 300, 20, 3%                                         | 7                             | Low engagement         | Rewrite intro, optimize for keywords |
| BLOG007    | Blog Post    | 2000, 70, 1.5%                                      | 6                             | Below average downloads| Improve readability, add relevant visuals |
| WP002      | Whitepaper   | 1000, 120, 1.8%                                     | 5                             | Broad appeal           | Segment for specific niche, A/B test new title |
"""

output_format_notes = {
    "What changed": "Added the 'Output Format' layer to the prompt, requesting a structured markdown table with specific columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'.",
    "What improved": "The AI output is now presented in a clear, structured, and easily digestible table format, which makes the recommendations immediately actionable and comparable. It provides specific data points and concrete suggestions.",
    "What still failed": "While the format is improved, the actual 'Refresh Priority Score' is still arbitrary (1-10) and not based on a quantifiable, explainable methodology derived from the provided context metrics. The 'Key Reason for Refresh' also lacks quantitative backing.",
    "What to try next": "Add the 'Quality Criteria' layer to the prompt to define specific, quantifiable metrics or rules for assigning priority scores and justifying refresh reasons."
}

print("Output Format Prompt:\n" + output_format_prompt)
print("\nRepresentative AI Output:\n" + output_format_output)
print("\nNotes:")
for key, value in output_format_notes.items():
    print(f"- {key}: {value}")
# Out:
# Output Format Prompt:
# Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles. The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards. Provide the recommendations in a structured markdown table with columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'.
#
# Representative AI Output:
#
# | Content ID | Content Type | Current Performance (Views, Downloads, Conversions) | Refresh Priority Score (1-10) | Key Reason for Refresh | Suggested Update Action |
# ...

# %% [markdown]
# **Reasoning**:
# I will define the prompt with the 'Quality Criteria' layer, simulate its AI output, and generate the corresponding notes as per the instructions for this subtask.

# %%
quality_criteria_layer = (
    " Assign a 'Refresh Priority Score' from 1-10 based on the following: Content with conversion rates below 1.5% and views above 1000 receive a base score of 7. For every 0.5% drop in conversion rate below 1.5%, add 1 point. For every 500 views above 1000, add 0.5 points. Content older than 18 months automatically receives +2 points. Content with recent negative feedback or significant topic shifts gets +3 points. The 'Key Reason for Refresh' must explicitly cite performance metrics (views, downloads, conversion rates) and content age/relevance."
)

quality_criteria_prompt = output_format_prompt + quality_criteria_layer

quality_criteria_output = """
| Content ID | Content Type | Current Performance (Views, Downloads, Conversions) | Refresh Priority Score (1-10) | Key Reason for Refresh | Suggested Update Action |
|------------|--------------|-----------------------------------------------------|-------------------------------|------------------------|-------------------------|
| BLOG001    | Blog Post    | 1500, 50, 2%                                        | 7                             | Conversion rate (2%) is above threshold, but views are high, suggest minor update. | Optimize keywords, add internal links |
| WP003      | Whitepaper   | 800, 100, 1%                                        | 9                             | Conversion rate (1%) below threshold (1.5%), content > 18 months old. | Research new trends, cite new sources, update visuals |
| CS005      | Case Study   | 300, 20, 3%                                         | 5                             | High conversion (3%) but low engagement (300 views). | Promote more effectively, refresh intro for SEO |
| BLOG007    | Blog Post    | 2000, 70, 1.5%                                      | 8                             | Conversion rate (1.5%) is at threshold, but very high views (2000) indicate high potential. | Improve readability, add relevant visuals, stronger CTA |
| WP002      | Whitepaper   | 1000, 120, 1.8%                                     | 6                             | Conversion rate (1.8%) above threshold, but content is 15 months old. | Segment for specific niche, A/B test new title with fresh data |
"""

quality_criteria_notes = {
    "What changed": "Added the 'Quality Criteria' layer to the prompt, defining quantifiable rules for assigning priority scores and justifying refresh reasons based on performance metrics, content age, and relevance.",
    "What improved": "The AI output now provides a more structured and justifiable 'Refresh Priority Score' and 'Key Reason for Refresh' by explicitly linking them to the defined metrics and criteria (conversion rates, views, content age). This makes the recommendations much less arbitrary and more actionable.",
    "What still failed": "While much more quantitative, the scoring system is still a simplified model. A more sophisticated model might consider trends over time (e.g., declining conversion), not just absolute values. The suggested update actions are still somewhat generic.",
    "What to try next": "Generate a final, polished prompt that combines all successful layers for a reusable prompt, then compile all prompts, outputs, and notes into a final document."
}

print("Quality Criteria Prompt:\n" + quality_criteria_prompt)
print("\nRepresentative AI Output:\n" + quality_criteria_output)
print("\nNotes:")
for key, value in quality_criteria_notes.items():
    print(f"- {key}: {value}")
# Out:
# Quality Criteria Prompt:
# ...

# %% [markdown]
# ## Generate Final Reusable Prompt
#
# ### Subtask:
# Create one final, polished, and reusable prompt for 'Content Refresh Priority Prediction' that another FlyRank intern could directly use, based on the iterative improvements.

# %% [markdown]
# **Reasoning**:
# I will combine all the previously defined prompt layers into a single, cohesive `final_prompt` string, as per the first instruction of the subtask. This will create the complete and polished prompt.

# %%
final_prompt = clear_goal_prompt + context_layer + output_format_layer + quality_criteria_layer

print("Final Reusable Prompt:\n" + final_prompt)
# Out:
# Final Reusable Prompt:
# ...

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Compile all generated prompts, representative AI outputs, and the corresponding notes into a clean, professional document. The document will conclude with a short summary: 'This prompt ladder demonstrates how incremental prompt engineering improves AI responses by adding one layer at a time. The final prompt is reusable by other FlyRank interns for Content Refresh Priority Prediction tasks.'

# %% [markdown]
# # Task
# The main goal is to demonstrate iterative prompt engineering for 'Content Refresh Priority Prediction'. This involves starting with a baseline prompt and progressively adding layers (Clear Goal, Audience, Context, Output Format, Quality Criteria) to improve AI outputs. Finally, all generated prompts, representative AI outputs, and corresponding notes will be compiled into a professional document with a summary explaining the prompt ladder approach.

# %% [markdown]
# ## Compile Final Document
#
# ### Subtask:
# Compile all generated prompts, representative AI outputs, and notes into a professional markdown document, ensuring all instances of 'Simulated AI Output' are replaced with 'Representative AI Output (Excerpt)' and that the document concludes with a summary about the prompt ladder's reusability.

# %% [markdown]
# ```markdown
# # Prompt Ladder: Content Refresh Priority Prediction
# ```

# %% [markdown]
# ```markdown
# This document details an iterative prompt engineering process, known as the 'Prompt Ladder,' applied to the task of 'Content Refresh Priority Prediction.' We start with a basic prompt and progressively enhance it by adding layers: Clear Goal, Audience, Context, Output Format, and Quality Criteria. Each step demonstrates how adding specific instructions refines AI output, leading to a more precise, actionable, and contextually relevant response.
#
# ---
#
# ## 1. Baseline Prompt: The Foundation
# ```

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# Identify content that needs updating based on current relevance and performance. Prioritize content that is outdated or underperforming. Suggest refreshing content that aligns with current trends or user needs. Consider content that has high traffic but low conversion rates for refresh. Evaluate content based on last updated date and content decay.
# ```
#
# ### Notes:
# *   **What changed**: This is the baseline prompt, so no changes from a previous iteration.
# *   **What improved**: The AI provided a general, albeit vague, understanding of content refresh priority.
# *   **What still failed**: The output is too generic and lacks specific criteria or actionable insights for prioritization. It's not tailored to any specific context or goal.
# *   **What to try next**: Add a 'Clear Goal' layer to the prompt to define what success looks like for the prediction.
#
# ---
#
# ## 2. Improve Prompt - Clear Goal

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority to maximize user engagement and conversion rates."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# Identify content pieces with declining engagement or low conversion metrics. Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups. Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to user intent. Consider A/B testing refreshed content versions to validate improvements in engagement and conversion. Focus on content that directly supports business goals and revenue generation.
# ```
#
# ### Notes:
# *   **What changed**: Added a 'Clear Goal' layer to the prompt: 'to maximize user engagement and conversion rates'.
# *   **What improved**: The AI output is now more focused on specific metrics (engagement, conversion) and provides actionable suggestions directly tied to achieving the defined goal, moving beyond general advice.
# *   **What still failed**: While more focused, the output still lacks specific audience context or detailed criteria for how to measure 'potential to increase'. It assumes a generic user base and doesn't specify the 'who' or 'how'.
# *   **What to try next**: Add the 'Audience' layer to the prompt to define the target user group.
#
# ---
#
# ## 3. Improve Prompt - Audience
# ```

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# Identify content pieces with declining engagement or low conversion metrics relevant to tech-savvy marketing professionals.Prioritize content that, if refreshed, has the highest potential to increase click-through rates and sign-ups among this demographic.Suggest updates that include clearer calls-to-action, improved readability, and updated information relevant to their professional needs.Consider A/B testing refreshed content versions to validate improvements in engagement and conversion for this audience.Focus on content that directly supports business goals and revenue generation by appealing to this specific user group.
# ```
#
# ### Notes:
# *   **What changed**: Added the 'Audience' layer to the prompt: 'The target audience for this content is tech-savvy young professionals working in marketing roles.'.
# *   **What improved**: The AI output now vaguely considers the specified audience, mentioning 'tech-savvy marketing professionals' and 'their professional needs'.
# *   **What still failed**: While the audience is mentioned, the output still lacks specific criteria or actionable insights tailored to *how* to measure 'potential to increase' for this audience, and adding the audience alone did not significantly improve prediction accuracy or overall quality beyond a generic mention.
# *   **What to try next**: Add the 'Context' layer to the prompt to provide more specific operational details and constraints.
#
# ---
#
# ## 4. Improve Prompt - Context
# ```

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles. The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# Identify blog posts, whitepapers, and case studies with declining views, downloads, or conversion rates, particularly those relevant to tech-savvy marketing professionals.Prioritize the 10-15 content pieces per quarter that, if refreshed, have the highest potential to increase engagement and conversions, utilizing A/B testing insights.Suggest updates that include clearer CTAs and improved readability, ensuring content aligns with professional needs and leverages CMS tracking data.Focus refresh efforts on content types and topics that historically drive high engagement and conversion for the target audience.Recommend A/B testing strategies for refreshed content versions to validate improvements in key metrics tracked by the CMS.
# ```
#
# ### Notes:
# *   **What changed**: Added the 'Context' layer to the prompt, detailing content inventory, CMS tracking, team capacity (10-15 pieces/quarter), and available tools (A/B testing, analytics dashboards).
# *   **What improved**: The AI output is now more specific, incorporating operational details like content types, metrics tracked by the CMS (views, downloads, conversion events), and the quarterly capacity for refreshing content. It also suggests using A/B testing insights.
# *   **What still failed**: While improved, the output still lacks concrete, quantifiable metrics for what constitutes 'high potential' or 'declining' within the given context. It doesn't provide a specific framework for prioritization given the constraints, or how to use the dashboards effectively.
# *   **What to try next**: Add the 'Output Format' layer to the prompt to ensure structured and easily digestible recommendations, potentially including specific fields or a table format.
#
# ---
#
# ## 5. Improve Prompt - Output Format
# ```

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles. The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards. Provide the recommendations in a structured markdown table with columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# | Content ID | Content Type | Current Performance (Views, Downloads, Conversions) | Refresh Priority Score (1-10) | Key Reason for Refresh | Suggested Update Action |
# |------------|--------------|-----------------------------------------------------|-------------------------------|------------------------|-------------------------|
# | BLOG001    | Blog Post    | 1500, 50, 2%                                        | 9                             | Declining conversions  | Update CTA, add new stats |
# | WP003      | Whitepaper   | 800, 100, 1%                                        | 8                             | Outdated data          | Research new trends, cite new sources |
# | CS005      | Case Study   | 300, 20, 3%                                         | 7                             | Low engagement         | Rewrite intro, optimize for keywords |
# | BLOG007    | Blog Post    | 2000, 70, 1.5%                                      | 6                             | Below average downloads| Improve readability, add relevant visuals |
# | WP002      | Whitepaper   | 1000, 120, 1.8%                                     | 5                             | Broad appeal           | Segment for specific niche, A/B test new title |
# ```
#
# ### Notes:
# *   **What changed**: Added the 'Output Format' layer to the prompt, requesting a structured markdown table with specific columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'.
# *   **What improved**: The AI output is now presented in a clear, structured, and easily digestible table format, which makes the recommendations immediately actionable and comparable. It provides specific data points and concrete suggestions.
# *   **What still failed**: While the format is improved, the actual 'Refresh Priority Score' is still arbitrary (1-10) and not based on a quantifiable, explainable methodology derived from the provided context metrics. The 'Key Reason for Refresh' also lacks quantitative backing.
# *   **What to try next**: Add the 'Quality Criteria' layer to the prompt to define specific, quantifiable metrics or rules for assigning priority scores and justifying refresh reasons.
#
# ---
#
# ## 6. Improve Prompt - Quality Criteria

# %% [markdown]
# ```markdown
# ### Prompt:
# ```python
# "Predict content refresh priority to maximize user engagement and conversion rates. The target audience for this content is tech-savvy young professionals working in marketing roles. The content inventory consists of blog posts, whitepapers, and case studies, managed within a content management system (CMS) that tracks views, downloads, and conversion events. Our team capacity allows for refreshing approximately 10-15 pieces of content per quarter. We have access to A/B testing tools and basic analytics dashboards. Provide the recommendations in a structured markdown table with columns: 'Content ID', 'Content Type', 'Current Performance (Views, Downloads, Conversions)', 'Refresh Priority Score (1-10)', 'Key Reason for Refresh', 'Suggested Update Action'. Assign a 'Refresh Priority Score' from 1-10 based on the following: Content with conversion rates below 1.5% and views above 1000 receive a base score of 7. For every 0.5% drop in conversion rate below 1.5%, add 1 point. For every 500 views above 1000, add 0.5 points. Content older than 18 months automatically receives +2 points. Content with recent negative feedback or significant topic shifts gets +3 points. The 'Key Reason for Refresh' must explicitly cite performance metrics (views, downloads, conversion rates) and content age/relevance."
# ```
#
# ### Representative AI Output (Excerpt):
# ```
# | Content ID | Content Type | Current Performance (Views, Downloads, Conversions) | Refresh Priority Score (1-10) | Key Reason for Refresh | Suggested Update Action |
# |------------|--------------|-----------------------------------------------------|-------------------------------|------------------------|-------------------------|
# | BLOG001    | Blog Post    | 1500, 50, 2%                                        | 7                             | Conversion rate (2%) is above threshold, but views are high, suggest minor update. | Optimize keywords, add internal links |
# | WP003      | Whitepaper   | 800, 100, 1%                                        | 9                             | Conversion rate (1%) below threshold (1.5%), content > 18 months old. | Research new trends, cite new sources, update visuals |
# | CS005      | Case Study   | 300, 20, 3%                                         | 5                             | High conversion (3%) but low engagement (300 views). | Promote more effectively, refresh intro for SEO |
# | BLOG007    | Blog Post    | 2000, 70, 1.5%                                      | 8                             | Conversion rate (1.5%) is at threshold, but very high views (2000) indicate high potential. | Improve readability, add relevant visuals, stronger CTA |
# | WP002      | Whitepaper   | 1000, 120, 1.8%                                     | 6                             | Conversion rate (1.8%) above threshold, but content is 15 months old. | Segment for specific niche, A/B test new title with fresh data |
# ```
#
# ### Notes:
# *   **What changed**: Added the 'Quality Criteria' layer to the prompt, defining quantifiable rules for assigning priority scores and justifying refresh reasons based on performance metrics, content age, and relevance.
# *   **What improved**: The AI output now provides a more structured and justifiable 'Refresh Priority Score' and 'Key Reason for Refresh' by explicitly linking them to the defined metrics and criteria (conversion rates, views, content age). This makes the recommendations much less arbitrary and more actionable.
# *   **What still failed**: While much more quantitative, the scoring system is still a simplified model. A more sophisticated model might consider trends over time (e.g., declining conversion), not just absolute values. The suggested update actions are still somewhat generic.
# *   **What to try next**: Generate a final, polished prompt that combines all successful layers for a reusable prompt, then compile all prompts, outputs, and notes into a final document.
#
# ---
#
# ## 6. Improve Prompt - Quality Criteria

# %% [markdown]
# ```markdown
# ## Summary
#
# This prompt ladder demonstrates how incremental prompt engineering improves AI responses by adding one layer at a time. The final prompt is reusable by other FlyRank interns for Content Refresh Priority Prediction tasks.
# ```
